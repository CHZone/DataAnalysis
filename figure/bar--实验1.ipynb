# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
name_list = ['VDSM','指数平滑','SVR','BPNN']
# 所有线路
num_list = [7.458, 9.819, 9.681, 9.602]  
# 线路3-8
num_list1 = [5.79, 9.621, 9.513, 9.4]  
# 线路1-2、9-10
num_list2 = [9.96, 10.115, 9.932, 9.905]
X =list(range(len(num_list)))  

plt.figure(figsize=(9,5)) 
# 绘制所有线路
plt.bar(X, num_list, width=0.22, label='线路1-10',tick_label = name_list,facecolor = 'lightskyblue',edgecolor='white')  
#  添加数字
for x,y in zip(X,num_list):
    plt.text(x+0.12,y+0.05,'%.3f' %y, ha='center')
    
for i in range(len(X)):  
    X[i] = X[i] + 0.22  

# 绘制线路3-8
plt.bar(X, num_list1, width=0.22, label='线路3-8',tick_label = name_list,facecolor = 'yellowgreen',edgecolor='white')  

for x,y in zip(X,num_list1):
    plt.text(x+0.12,y+0.05,'%.3f' %y, ha='center')
    
for i in range(len(X)):  
    X[i] = X[i] + 0.22 
    
# 绘制线路1-2， 9-10
plt.bar(X, num_list2, width=0.22, label='线路1-2,9-10',tick_label = name_list,facecolor = 'yellow',edgecolor='white')  

for x,y in zip(X,num_list2):
    plt.text(x+0.12,y+0.05,'%.3f' %y, ha='center')
plt.legend(loc='lower right')  

plt.ylabel('MAPE(%)')
plt.xlabel('模型')
plt.title('各模型预测结果的 MAPE(%)')
plt.show()

# %%
name_list = ['VDSM','指数平滑','SVR','BPNN']
# 所有线路
num_list = [1.275, 1.65, 1.532, 1.604]  
# 线路3-8
num_list1 = [1.121, 1.736, 1.581, 1.678]  
# 线路1-2、9-10
num_list2 = [1.505, 1.52, 1.4575, 1.492]
X =list(range(len(num_list)))  

plt.figure(figsize=(9,5)) 
# 绘制所有线路
plt.bar(X, num_list, width=0.22, label='线路1-10',tick_label = name_list,facecolor = 'lightskyblue',edgecolor='white')  
#  添加数字
for x,y in zip(X,num_list):
    plt.text(x+0.12,y+0.01,'%.3f' %y, ha='center')
    
for i in range(len(X)):  
    X[i] = X[i] + 0.22  

# 绘制线路3-8
plt.bar(X, num_list1, width=0.22, label='线路3-8',tick_label = name_list,facecolor = 'yellowgreen',edgecolor='white')  

for x,y in zip(X,num_list1):
    plt.text(x+0.12,y+0.01,'%.3f' %y, ha='center')
    
for i in range(len(X)):  
    X[i] = X[i] + 0.22 
    
# 绘制线路1-2， 9-10
plt.bar(X, num_list2, width=0.22, label='线路1-2,9-10',tick_label = name_list,facecolor = 'yellow',edgecolor='white')  

for x,y in zip(X,num_list2):
    plt.text(x+0.12,y+0.01,'%.3f' %y, ha='center')
plt.legend(loc='lower right')  

plt.ylabel('RMSE(h)')
plt.xlabel('模型')
plt.title('10条线路中各模型预测结果的平均 RMSE(h)')
plt.show()

# %%
name_list = ['线路1-10','线路3-8','线路1-2,9-10']
# 所有线路
num_list = [7.458, 9.819, 9.681, 9.602]  
# 线路3-8
num_list1 = [5.79, 9.621, 9.513, 9.4]  
# 线路1-2、9-10
num_list2 = [9.96, 10.115, 9.932, 9.905]

VDSM_list = [7.458, 5.79, 9.96]
smooth_list = [9.819, 9.621, 10.115]
svr_list = [9.681, 9.513, 9.932]
bp_list = [9.602, 9.4, 9.905]


X =list(range(len(VDSM_list)))  

plt.figure(figsize=(9,5)) 
# VDSM
plt.bar(X, VDSM_list, width=0.22, label='线路1-10',tick_label = name_list,facecolor = 'lightskyblue',edgecolor='white')  
#  添加数字
for x,y in zip(X,VDSM_list):
    plt.text(x+0.12,y+0.05,'%.3f' %y, ha='center')
    
# smooth
for i in range(len(X)):  
    X[i] = X[i] + 0.22  
plt.bar(X, smooth_list, width=0.22, label='线路3-8',tick_label = name_list,facecolor = 'yellowgreen',edgecolor='white')  

for x,y in zip(X,smooth_list):
    plt.text(x+0.12,y+0.05,'%.3f' %y, ha='center')
    
# SVR
for i in range(len(X)):  
    X[i] = X[i] + 0.22 
plt.bar(X, svr_list, width=0.22, label='线路1-2,9-10',tick_label = name_list,facecolor = 'yellow',edgecolor='white')  

for x,y in zip(X,svr_list):
    plt.text(x+0.12,y+0.05,'%.3f' %y, ha='center')

# BP
for i in range(len(X)):  
    X[i] = X[i] + 0.22  
plt.bar(X, bp_list, width=0.22, label='线路1-2,9-10',tick_label = name_list,facecolor = 'yellow',edgecolor='white')  

for x,y in zip(X,bp_list):
    plt.text(x+0.12,y+0.05,'%.3f' %y, ha='center') 
    
plt.legend(loc='lower right')  
plt.ylabel('MAPE(%)')
plt.xlabel('模型')
plt.title('各模型预测结果的 MAPE(%)')
plt.show()
